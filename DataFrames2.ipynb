# %% [markdown]
# # DataFrames Filtering

# %%
import pandas as pd

# %%
df = pd.read_csv("data/employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# ## reduce size to improve performance of filtering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
# missing values will get today's date, so probably best to fill with some value before converting
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-04-29 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-29 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-29 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-29 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## user parse_dates argument

# %%
# automatically covert string to date
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date", "Last Login Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %% [markdown]
# ## filtering

# %%
# filter by gender
df[df["Gender"] == "Male"].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2020-04-29 01:35:00  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
# filter with not equals
df[df["Team"] != "Finance"].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 4      Larry    Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2020-04-29 01:35:00  115163   10.125
# 6       Ruby  Female 1987-08-17 2020-04-29 16:20:00   65476   10.012
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 4              True  Client Services
# 5             False            Legal
# 6              True          Product

# %%
# filtering with multiple series
# use & (and) | (or) ~ (not)
filter_gender = df["Gender"] == "Male"
filter_team = df["Team"] == "Marketing"

df[filter_gender & filter_team].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2020-04-29 01:35:00  115163   10.125
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True  Marketing
# 3              True  Marketing
# 4              True  Marketing
# 5             False  Marketing

# %% [markdown]
# ## using .isin() method

# %%
# filter rows where team is Legal, Sales, Product
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date", "Last Login Time"])

# use | condition or
filter_team = df["Team"].isin(["Legal", "Sales", "Product"])
df[filter_team].head(12)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2020-04-29 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2020-04-29 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2020-04-29 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2020-04-29 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2020-04-29 06:09:00   59414    1.256
# 17      Shawn    Male 1986-12-07 2020-04-29 19:45:00  111737    6.414
# 19      Donna  Female 2010-07-22 2020-04-29 03:48:00   81014    1.894
# 20       Lois     NaN 1995-04-22 2020-04-29 19:18:00   64714    4.934
# 27      Scott     NaN 1991-07-11 2020-04-29 18:58:00  122367    5.218
# 29   Benjamin    Male 2005-01-26 2020-04-29 22:06:00   79529    7.008
# 31      Joyce     NaN 2005-02-20 2020-04-29 14:40:00   88657   12.752
# 35    Theresa  Female 2006-10-10 2020-04-29 01:12:00   85182   16.675
#
#    Senior Management     Team
# 5              False    Legal
# 6               True  Product
# 11              True    Legal
# 13             False    Sales
# 15             False  Product
# 17             False  Product
# 19             False  Product
# 20              True    Legal
# 27             False    Legal
# 29              True    Legal
# 31             False  Product
# 35             False    Sales

# %% [markdown]
# ## .isnull() and .notnull()

# %%
# filter where Gender is null
df[df["Gender"].isnull()].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 20       Lois    NaN 1995-04-22 2020-04-29 19:18:00   64714    4.934
# 22     Joshua    NaN 2012-03-08 2020-04-29 01:58:00   90816   18.816
# 27      Scott    NaN 1991-07-11 2020-04-29 18:58:00  122367    5.218
# 31      Joyce    NaN 2005-02-20 2020-04-29 14:40:00   88657   12.752
# 41  Christine    NaN 2015-06-28 2020-04-29 01:08:00   66582   11.308
#
#    Senior Management                  Team
# 20              True                 Legal
# 22              True       Client Services
# 27             False                 Legal
# 31             False               Product
# 41              True  Business Development

# %%
# filter where Gender is not null
df[df["Gender"].notnull()].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-29 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %% [markdown]
# ## between() method

# %%
df[df["Salary"].between(60000, 90000, inclusive=True)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2020-04-29 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2020-04-29 09:01:00   63241   15.132
# 19      Donna  Female 2010-07-22 2020-04-29 03:48:00   81014    1.894
# 20       Lois     NaN 1995-04-22 2020-04-29 19:18:00   64714    4.934
#
#    Senior Management     Team
# 1               True      NaN
# 6               True  Product
# 10              True      NaN
# 19             False  Product
# 20              True    Legal

# %%
df[df["Last Login Time"].between("08:30AM", "01:00PM", inclusive=True)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 2       Maria  Female 1993-04-23 2020-04-29 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2020-04-29 10:43:00   45906   11.598
# 10     Louise  Female 1980-08-12 2020-04-29 09:01:00   63241   15.132
#
#    Senior Management       Team
# 0               True  Marketing
# 2              False    Finance
# 3               True    Finance
# 7                NaN    Finance
# 10              True        NaN

# %% [markdown]
# ## duplicated() method

# %%
# returns first instance of rows that have duplicated First Name values
df[df["First Name"].duplicated(keep="first")].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 23        NaN    Male 2012-06-14 2020-04-29 16:19:00  125792    5.042
# 25        NaN    Male 2012-10-08 2020-04-29 01:12:00   37076   18.576
# 32        NaN    Male 1998-08-21 2020-04-29 14:27:00  122340    6.417
# 34      Jerry    Male 2004-01-10 2020-04-29 12:56:00   95734   19.096
# 39        NaN    Male 2016-01-29 2020-04-29 02:33:00  122173    7.797
# 51        NaN     NaN 2011-12-17 2020-04-29 08:29:00   41126   14.009
# 58    Theresa  Female 2010-04-11 2020-04-29 07:18:00   72670    1.481
# 62        NaN  Female 2007-06-12 2020-04-29 17:25:00   58112   19.414
# 63    Matthew    Male 2013-01-02 2020-04-29 22:33:00   35203   18.040
# 66      Nancy  Female 2012-12-15 2020-04-29 23:57:00  125250    2.672
#
#    Senior Management                  Team
# 23               NaN                   NaN
# 25               NaN       Client Services
# 32               NaN                   NaN
# 34             False       Client Services
# 39               NaN       Client Services
# 51               NaN                 Sales
# 58              True           Engineering
# 62               NaN             Marketing
# 63             False       Human Resources
# 66              True  Business Development

# %%
# returns all rows that have duplicated First Name values
df[df["First Name"].duplicated(keep=False)].sort_values("First Name").head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 440      Aaron   Male 1990-07-22 2020-04-29 14:53:00   52119   11.343
# 327      Aaron   Male 1994-01-29 2020-04-29 18:48:00   58755    5.097
# 101      Aaron   Male 2012-02-17 2020-04-29 10:20:00   61602   11.849
# 937      Aaron    NaN 1986-01-22 2020-04-29 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2020-04-29 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2020-04-29 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2020-04-29 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2020-04-29 21:53:00   45181    3.491
# 610       Alan   Male 2012-02-17 2020-04-29 00:26:00   41453   10.084
# 53        Alan    NaN 2014-03-03 2020-04-29 13:28:00   40341   17.578
#
#     Senior Management             Team
# 440              True  Client Services
# 327              True        Marketing
# 101              True        Marketing
# 937             False  Client Services
# 137             False     Distribution
# 141              True          Product
# 302              True  Human Resources
# 538             False  Human Resources
# 610             False          Product
# 53               True          Finance

# %%
# use tilda to negate the results
# returns rows with unique First Name
df[~df["First Name"].duplicated(keep=False)].sort_values("First Name").head(10)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-04-29 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-04-29 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-04-29 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-04-29 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-04-29 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-04-29 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-04-29 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-04-29 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-04-29 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# 5               False                 Legal
# 495             False                 Sales
# 33              False  Business Development
# 832             False                 Legal
# 291              True       Client Services

# %% [markdown]
# ## drop_duplicates() method

# %%
# need to specify subset, else will look for dups across the row
# will keep the first row
df = df.drop_duplicates(subset=["First Name"], keep= "first")

# %%
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date", "Last Login Time"])
# where First Name is repeated in same Team
df.drop_duplicates(subset=["First Name", "Team"], keep= "first", inplace=True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-29 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-29 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-29 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-29 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-29 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-04-29 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2020-04-29 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-29 06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20 2020-04-29 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-29 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 994              True             Marketing
# 995             False          Distribution
# 996             False               Finance
# 998             False  Business Development
# 999              True                 Sales
#
# [769 rows x 8 columns]

# %% [markdown]
# ## unique() and nunique()

# %%
# returns an array of all unique values within Gender
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
# returns the count of non-null unique values
# set dropna parameter if null values should count
df["Gender"].nunique()
# Out:
# 2
